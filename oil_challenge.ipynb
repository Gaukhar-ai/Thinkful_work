# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaukhar-ai/Thinkful_work/blob/master/oil_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup

# %%
finviz_url = 'https://finviz.com/quote.ashx?t='
tickers = ['SNP', 'PTR', 'RDS.A', 'BP', 'XOM', 'TOT', 'CVX', 'MPC']

# %%
news_tables = {}
for ticker in tickers:
  url = finviz_url + ticker

  req = Request(url=url, headers={'user-agent': 'my-app'})
  response = urlopen(req)
  
  html = BeautifulSoup(response, 'html')
  print(html)

  break
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html>
# <head>
# <title>SNP China Petroleum &amp; Chemical Corporation Stock Quote</title>
# <meta content="Stock screener for investors and traders, financial visualizations." name="description"/>
# <meta content="Stock Screener, Charts, Quotes, Maps, News, Financial Visualizations, Research, Trading Systems" name="keywords"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <meta content="-1" http-equiv="Expires"/>
# <link href="//fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet" type="text/css"/><link href="/css/finviz_old.css?rev=150" rel="stylesheet" type="text/css"/>
# <link href="/favicon_2x.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon.png" rel="icon" sizes="16x16" type="image/png"/>
# <script src="/script/boxover.js?rev=247" type="text/javascript"></script>
# ...

# %%
news_table = html.find(id='news-table')
news_tables[ticker] = news_table
print(news_tables)
# Out:
# {'SNP': <table border="0" cellpadding="1" cellspacing="0" class="fullview-news-outer" id="news-table" width="100%">
# <tr><td align="right" style="white-space:nowrap" width="130">Oct-28-20 11:05PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/sinopecs-net-profit-2020-q3-030500659.html" target="_blank">Sinopec's Net Profit for 2020 Q3 Reached RMB 23.507 Billion Campaign of Continuously Tiding Over Difficulties and Improving Performances Achieves Favorable Results with Significant Improvement of Operation and Profitability</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> ACCESSWIRE</span></div></div></td></tr>
# ...

# %%
bp_data = news_tables['BP']
bp_rows = bp_data.findAll('tr')

for index, row in enumerate(bp_rows):
  title=row.a.text
  print(title)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-76cbd94b699f> in <module>()
# ----> 1 bp_data = news_tables['BP']
#       2 bp_rows = bp_data.findAll('tr')
#       3
#       4 for index, row in enumerate(bp_rows):
#       5   title=row.a.text
#
# KeyError: 'BP'
